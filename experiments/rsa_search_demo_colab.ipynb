# %% [markdown]
# # Random Semantic Algebra — Search Demo
# Interactive search demo: dense retrieval → semantic program → cheap RSA pruning → side-by-side results.
#
# Default example: `black men's shoes not sports`. The searchable catalog is held out from predicate training.

# %%
# !pip -q install datasets sentence-transformers scikit-learn pandas numpy pyarrow ipywidgets

# %%
import base64, gzip, urllib.request
url='https://raw.githubusercontent.com/hanialshater/LSH_Memory/refs/heads/rsa-v2-colab/experiments/rsa_search_demo.part0'
blob=urllib.request.urlopen(url).read().decode()
exec(gzip.decompress(base64.b64decode(blob)).decode())
